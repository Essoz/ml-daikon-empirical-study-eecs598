# %%
import json
import matplotlib.pyplot as plt

# %%
res = json.load(open('./case_3_res.json', 'r'))

# %%
res_lr = json.load(open('./fixes3_remove_normalization/case_3_res.json', 'r'))

# %%
res
# plot the loss and validation loss with the number of epochs
loss = [r['loss'] for r in res]
val_loss = [r['valid_loss'] for r in res]
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss', 'val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Loss curves of the original pipeline')
plt.show()

# plot the accuracy and validation accuracy with the number of epochs
acc = [r['Valid_Accuracy'] / 100 for r in res]
plt.plot(acc)
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.title('Validation Accuracy of the original pipeline')
# Out:
# Text(0.5, 1.0, 'Validation Accuracy of the original pipeline')

# %%
# res_lr lr
res_lr
# plot the loss and validation loss with the number of epochs
loss = [r['loss'] for r in res_lr]
val_loss = [r['valid_loss'] for r in res_lr]
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss', 'val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Loss curves of the saturated pipeline')
plt.show()

# plot the accuracy and validation accuracy with the number of epochs
acc = [r['Valid_Accuracy'] / 100 for r in res_lr]
plt.plot(acc)
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.title('Validation Accuracy of the saturated pipeline')
# Out:
# Text(0.5, 1.0, 'Validation Accuracy of the original pipeline')

# %%
res
# Out:
# [{'Epoch': 1,
#   'loss': 4.6120923974227885,
#   'valid_loss': 4.607842255544676,
#   'Valid_Accuracy': 1.01},
#  {'Epoch': 2,
#   'loss': 4.612798098640469,
#   'valid_loss': 4.607820213937759,
#   'Valid_Accuracy': 0.98},
#  {'Epoch': 3,
#   'loss': 4.612758343505878,
#   'valid_loss': 4.607763587379454,
#   'Valid_Accuracy': 0.98},
#  {'Epoch': 4,
#   'loss': 4.611656032829305,
#   'valid_loss': 4.60767128858566,
#   'Valid_Accuracy': 0.97},
#  {'Epoch': 5,
#   'loss': 4.61202960597993,
#   'valid_loss': 4.607907852745047,
#   'Valid_Accuracy': 1.0},
#  {'Epoch': 6,
#   'loss': 4.611330225372319,
#   'valid_loss': 4.608051021528207,
#   'Valid_Accuracy': 0.97},
#  {'Epoch': 7,
#   'loss': 4.6111686254882835,
#   'valid_loss': 4.6078444109916745,
#   'Valid_Accuracy': 0.98},
#  {'Epoch': 8,
#   'loss': 4.611971679840081,
#   'valid_loss': 4.607997022628769,
#   'Valid_Accuracy': 1.01},
#  {'Epoch': 9,
#   'loss': 4.612245825691223,
#   'valid_loss': 4.607768111562709,
# ...

# %%
# play with effificient net
from efficientnet_pytorch import EfficientNet
model_transfer = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
print(model_transfer)
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
# ...
